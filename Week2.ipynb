# %% [markdown]
# <a href="https://colab.research.google.com/github/salsabilawf/PCVK_Genap_2021/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/kitten01.jpeg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/kitten01.jpeg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],
[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2)) #nilai 2 untuk menunjukkan bahwa tiap titik dibuat 3 channel yg mewakili R,G,dan B
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# 1. Apakah perbedaan gambar yang ditampilkan tanpa dan dengan matplotlib?
#
# Di Matplotlib, gambar (contoh kelas plt.Figure) dapat dianggap sebagai wadah tunggal yang berisi semua objek yang mewakili sumbu, grafik, teks, dan label. Sumbu (contoh kelas plt.Axes) adalah apa yang kita lihat di atas: kotak pembatas dengan titik dan label, yang pada akhirnya akan berisi elemen plot yang membentuk visualisasi. Sepanjang buku ini, kita umumnya akan menggunakan nama variabel fig untuk merujuk ke contoh gambar, dan ax untuk merujuk ke instance sumbu atau grup instance sumbu. Sehingga kita dapat mengetahui lebih mudah koordinat object(gmabar) yang akan kita buat

# %% [markdown]
# 2. Apakah perbedaan dan pengaruhnya pembuatan black image antara tipe data int16
# dan int32?
#
# Int16 Ini adalah FCL type. Dalam C#, pendek dipetakan ke Int16. Ini adalah
# jenis nilai dan mewakili Sistem.Int16 struct.Hal ini ditandatangani dan
# membutuhkan 16 bit.Memiliki minimal -32768 dan maksimum +32767 nilai.
# Int32Ini adalah FCL type.Dalam C#, int dipetakan ke Int32.Ini adalah jenis nilai dan
# mewakili Sistem.Int32 struct.Hal ini ditandatangani dan membutuhkan 32
# bit.Memiliki minimal -2147483648 dan maksimum +2147483647 nilai.

# %% [markdown]
# 3. Jelaskan tentang angka-angka yang terdapat pada reshape((-1,1,2))
#
# Fungsi dari method tersebut adalah digunakan untuk merubah bentuk dari output dari array yang sebelumnya telah dibuat.

# %% [markdown]
# 4. Apakah kegunaan “google.colab.patches import cv2_imshow” pada potongan kode
# berikut
#
# Menampilkan gambar secara otomatis dari google drive tetapi warnanya berbalik
# menjadi
# BGR

# %% [markdown]
# 5. Apakah kegunaan “skimage impot io” pada potongan kode soal nomor 4
#
#  Untuk menyediakan fungsi konversi untuk gambar

# %% [markdown]
# **TUGAS**
# 1. Tampilkan image dalam channel Red-Green dan Green-Blue saja!

# %% [markdown]
# red-green

# %%
img = img.copy()
img[:,:,2] = 0
plt.imshow(img)

# %% [markdown]
# green-blue

# %%
img_gb = img
img_gb[:,:,0] = 0
plt.imshow(img_gb)

# %% [markdown]
# 2. Tampilkan image baris ke 10-100, kolom 10-100

# %%
img_k = img[10:100,10:100]
plt.imshow(img_k)

# %% [markdown]
# 3. Tampilkan image baris ke 5-30, semua kolom, channel Green saja!

# %%
plt.imshow(img[5:30])

# %% [markdown]
# 4. Buat 5 kotak berbagai ukuran dan warna yang berbeda dalam satu image.
# disarankan menggunakan bilangan acak/random!

# %%
img_ktk = cv.cvtColor(img, cv.COLOR_BGR2RGB)
cv.rectangle(img_ktk, pt1=(250,300), pt2=(80,150), color=(100,255,255), thickness=25)
cv.rectangle(img_ktk, pt1=(100,350), pt2=(150,150), color=(100,255,255), thickness=25)
cv.rectangle(img_ktk, pt1=(333,250), pt2=(450,150), color=(100,255,255), thickness=25)
cv.rectangle(img_ktk, pt1=(250,120), pt2=(320,250), color=(100,255,255), thickness=25)
cv.rectangle(img_ktk, pt1=(400,350), pt2=(550,250), color=(100,255,255), thickness=25)
plt.imshow(img_ktk)

# %% [markdown]
# 5. Tampilkan image dengan posisi terbalik!

# %%
img_tb = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)
fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(111)
ax.imshow(img_tb)

# %% [markdown]
# 6. Buat rectangle dan circle pada bagian wajah dari image kitten!

# %%
imgt = img
cv.rectangle(imgt,pt1=(250,100),pt2=(500,300),color=(0,0,255),thickness=15)
cv.circle(imgt,center=(400,200),radius=100,color=(255,0,0),thickness=8)
plt.imshow(imgt)

# %% [markdown]
# 7. Buat rectangle pada bagian sudut bawah kiri channel B pada color space RGB
# dari citra kitten01.jpg!

# %%
cv.rectangle(imgt,pt1=(100,300),pt2=(10,500),color=(0,255,0),thickness=10)
plt.imshow(imgt)
